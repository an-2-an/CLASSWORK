# %% [markdown]
# **Тема: Функции. Условный оператор**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here
