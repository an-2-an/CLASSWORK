# %% [markdown]
# **Тема: Строки**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
FILENAME = 'numbers.txt'

# code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)
